# %%
# import some Python dependencies

import urllib2
import json
import datetime
import csv
import time
import os

# %%
# Since the code output in this notebook leaks the app_secret,
# it has been reset by the time you read this.

app_id = os.getenv("FACEBOOK_APP_ID")
app_secret = os.getenv("FACEBOOK_APP_SECRET")

access_token = app_id + "|" + app_secret

# %%
page_id = 'nytimes'

# %%
def testFacebookPageData(page_id, access_token):
    
    # construct the URL string
    base = "https://graph.facebook.com/v2.4"
    node = "/" + page_id
    parameters = "/?access_token=%s" % access_token
    url = base + node + parameters
    
    # retrieve data
    req = urllib2.Request(url)
    response = urllib2.urlopen(req)
    data = json.loads(response.read())
    
    print json.dumps(data, indent=4, sort_keys=True)

# %%
testFacebookPageData(page_id, access_token)
# Out:
# {
#     "id": "5281959998",
#     "name": "The New York Times"
# }

# %%
def request_until_succeed(url):
    req = urllib2.Request(url)
    success = False
    while success is False:
        try: 
            response = urllib2.urlopen(req)
            if response.getcode() == 200:
                success = True
        except Exception, e:
            print e
            time.sleep(5)
            
            print "Error for URL %s: %s" % (url, datetime.datetime.now())

    return response.read()

# %%
def testFacebookPageFeedData(page_id, access_token):
    
    # construct the URL string
    base = "https://graph.facebook.com/v2.4"
    node = "/" + page_id + "/feed" # changed
    parameters = "/?access_token=%s" % access_token
    url = base + node + parameters
    
    # retrieve data
    data = json.loads(request_until_succeed(url))
    
    print json.dumps(data, indent=4, sort_keys=True)
    

testFacebookPageFeedData(page_id, access_token)
# Out:
# {
#     "data": [
#         {
#             "created_time": "2016-04-19T20:26:06+0000",
#             "id": "5281959998_10150793902249999",
#             "message": "He wiped blood onto his 5-year-old daughter's shirt. Then he changed his clothes and fled the scene."
#         },
#         {
#             "created_time": "2016-04-19T19:55:01+0000",
#             "id": "5281959998_10150793836489999",
#             "message": "The New York Yankees have the highest success rate challenging umpires' calls. The reason? This guy."
#         },
#         {
#             "created_time": "2016-04-19T19:37:01+0000",
#             "id": "5281959998_10150793864759999",
#             "message": "Alissa J. Rubin, who won a Pulitzer Prize for reporting on the abuse and injustice faced by women in Afghanistan and the troubled Western response to it, answers your questions.",
#             "story": "The New York Times was live."
#         },
#         {
#             "created_time": "2016-04-19T19:31:43+0000",
#             "id": "5281959998_10150793866374999",
#             "message": "Peter Liang, the former NYC police officer who fatally shot Akai Gurley in a stairwell while on patrol, won't go to prison."
#         },
#         {
#             "created_time": "2016-04-19T18:55:00+0000",
#             "id": "5281959998_10150793822684999",
#             "message": "A parrot that barks. A parrot that asks, \"What in the hell was that?\" A parrot that rolls over into a paper bag. We asked for an introduction to your feathered friends and you didn't disappoint."
#         },
#         {
#             "created_time": "2016-04-19T18:25:00+0000",
#             "id": "5281959998_10150793806744999",
#             "message": "He attacked her when his friends began mocking him for trying to pick up a transgender woman."
#         },
#         {
#             "created_time": "2016-04-19T17:55:00+0000",
#             "id": "5281959998_10150793793979999",
#             "message": "\"The families are going to pay to have their students flown here, but they\u2019re going to flunk out because they don\u2019t have the academic preparation, and then go home. That\u2019s not good.\""
#         },
#         {
#             "created_time": "2016-04-19T17:01:00+0000",
#             "id": "5281959998_10150793787639999",
#             "message": "Europe is set to charge Google with giving an unfair edge to its own services, like maps and search, on Android phones."
#         },
#         {
#             "created_time": "2016-04-19T16:30:33+0000",
#             "id": "5281959998_10150793771784999",
#             "message": "Out of Hillary Clinton, Bernie Sanders and Donald J. Trump, who's the New York-iest candidate? We're breaking it down live, using New York pizza. \ud83c\udf55\n\nThe original story: http://nyti.ms/1Xz7UfV",
#             "story": "The New York Times was live."
#         },
#         {
#             "created_time": "2016-04-19T16:26:57+0000",
#             "id": "5281959998_10150793770604999",
#             "message": "Over the past several months, Donald J. Trump has crisscrossed the country making campaign stops in his sleek Cessna jet. There is just one hitch: The plane\u2019s registration is expired."
#         },
#         {
#             "created_time": "2016-04-19T16:14:00+0000",
#             "id": "5281959998_10150793759674999",
#             "message": "Michael Strahan is trading one morning show for another."
#         },
#         {
#             "created_time": "2016-04-19T16:02:00+0000",
#             "id": "5281959998_10150793754704999",
#             "message": "When it started, \"Girls\" was received as an anthem for entitled white women. It\u2019s much more than that."
#         },
#         {
#             "created_time": "2016-04-19T15:25:00+0000",
#             "id": "5281959998_10150793725789999",
#             "message": "9-year-old Angiolina Cima-Turzio took a break as Bernie Sanders spoke at a campaign rally in Prospect Park in Brooklyn on Sunday. \n\nPhoto: Damon Winter/The New York Times (via instagram.com/nytimes)"
#         },
#         {
#             "created_time": "2016-04-19T14:55:00+0000",
#             "id": "5281959998_10150793632574999",
#             "message": "Here are some ways to travel a little more responsibly, even when taking that trip to Hawaii."
#         },
#         {
#             "created_time": "2016-04-19T14:25:00+0000",
#             "id": "5281959998_10150793686274999",
#             "message": "President Barack Obama is trying to buy off Saudi Arabia with weapons. The results are deadly. Read on in The New York Times Opinion Section."
#         },
#         {
#             "created_time": "2016-04-19T13:55:00+0000",
#             "id": "5281959998_10150793668924999",
#             "message": "Can the secret to the Iceland's happiness be found in its communal pools?"
#         },
#         {
#             "created_time": "2016-04-19T13:25:00+0000",
#             "id": "5281959998_10150793656814999",
#             "message": "\"Donald J. Trump and Bernie Sanders reduce pretty much all issues to the same single story: the alien invader story.\" Read on in The New York Times Opinion Section. http://nyti.ms/1VzBfcZ"
#         },
#         {
#             "created_time": "2016-04-19T12:55:00+0000",
#             "id": "5281959998_10150793621224999",
#             "message": "Parents and students should think of a gap year not as a break in an education, but as a part of it."
#         },
#         {
#             "created_time": "2016-04-19T12:25:00+0000",
#             "id": "5281959998_10150793620699999",
#             "message": "Lena Dunham is on Hillary Clinton's side. Rosario Dawson supports Bernie Sanders. See where other famous New Yorkers stand."
#         },
#         {
#             "created_time": "2016-04-19T11:55:00+0000",
#             "id": "5281959998_10150793631779999",
#             "message": "\"Our grandchildren could grow up knowing less about the planet than we do today. This is not a legacy we want to leave them. Yet we are on the verge of ensuring this happens.\" Read on in The New York Times Opinion Section."
#         },
#         {
#             "created_time": "2016-04-19T11:25:00+0000",
#             "id": "5281959998_10150793606879999",
#             "message": "Will the voting machines work? Will turnout be 'yuge'? Here are a few things to watch for in the New York primaries."
#         },
#         {
#             "created_time": "2016-04-19T10:55:00+0000",
#             "id": "5281959998_10150793579799999",
#             "message": "Merkel is right to seek Turkey's help in resolving the migrant crisis, but she should have made clear to Erdogan that Western freedoms were not on the table, the Editorial Board writes in The New York Times Opinion Section."
#         },
#         {
#             "created_time": "2016-04-19T10:30:00+0000",
#             "id": "5281959998_10150793610744999",
#             "message": "Daily Briefing: Here's what you need to know today."
#         },
#         {
#             "created_time": "2016-04-19T10:25:00+0000",
#             "id": "5281959998_10150793531199999",
#             "message": "\u201cI was down there, and I watched our police and our firemen, down on 7-Eleven, down at the World Trade Center, right after it came down,\u201d Donald J. Trump said on Monday night."
#         },
#         {
#             "created_time": "2016-04-19T09:45:31+0000",
#             "id": "5281959998_10150793593109999",
#             "message": "Breaking News: Terrorists in Kabul have killed dozens and wounded hundreds. The Taliban claimed responsibility."
#         }
#     ],
#     "paging": {
#         "next": "https://graph.facebook.com/v2.6/5281959998/feed?access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&limit=25&until=1461059131&__paging_token=enc_AdCcg8APm0uRT1XZCkzkfZBRfgpIZB7geZBuKvEpAPimr2TIjSpChXZBw0QHqYDEhr7EqgsibsNhhLIAosknBUsFiFvWp",
#         "previous": "https://graph.facebook.com/v2.6/5281959998/feed?since=1461097566&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&limit=25&__paging_token=enc_AdC46otay3CVei0euNsZB8wKhCLPCQQuL0ZAe2D2zVSSCIHJaMgpFGFwyA6DWg6FC9Fjc6MXmq1ln9pZAFT7hs45AIX&__previous=1"
#     }
# }

# %%
def getFacebookPageFeedData(page_id, access_token, num_statuses):
    
    # construct the URL string
    base = "https://graph.facebook.com"
    node = "/" + page_id + "/feed" 
    parameters = "/?fields=message,link,created_time,type,name,id,likes.limit(1).summary(true),comments.limit(1).summary(true),shares&limit=%s&access_token=%s" % (num_statuses, access_token) # changed
    url = base + node + parameters
    
    # retrieve data
    data = json.loads(request_until_succeed(url))
    
    return data
    

test_status = getFacebookPageFeedData(page_id, access_token, 1)["data"][0]
print json.dumps(test_status, indent=4, sort_keys=True)
# Out:
# {
#     "comments": {
#         "data": [
#             {
#                 "created_time": "2016-04-19T20:29:51+0000",
#                 "from": {
#                     "id": "10153597244488963",
#                     "name": "Karen Crook"
#                 },
#                 "id": "10150793902249999_10150793904884999",
#                 "message": "What a disgusting excuse for a human being!!!! Not only did he kill his daughter, he then assaulted his other daughter and put the blame on her. Revolting! I hope they throw the book at this pathetic human."
#             }
#         ],
#         "paging": {
#             "cursors": {
#                 "after": "MwZDZD",
#                 "before": "MwZDZD"
#             },
#             "next": "https://graph.facebook.com/v2.6/5281959998_10150793902249999/comments?access_token=1588347538160720%7Cd77eae2a264f512a1acb6f84df6bc29b&summary=true&limit=1&after=MwZDZD"
#         },
#         "summary": {
#             "can_comment": false,
#             "order": "ranked",
#             "total_count": 3
#         }
#     },
#     "created_time": "2016-04-19T20:26:06+0000",
#     "id": "5281959998_10150793902249999",
#     "likes": {
#         "data": [
#             {
#                 "id": "599665130186264",
#                 "name": "Syed Abdullah Shah"
#             }
#         ],
#         "paging": {
#             "cursors": {
#                 "after": "NTk5NjY1MTMwMTg2MjY0",
#                 "before": "NTk5NjY1MTMwMTg2MjY0"
#             },
#             "next": "https://graph.facebook.com/v2.6/5281959998_10150793902249999/likes?access_token=1588347538160720%7Cd77eae2a264f512a1acb6f84df6bc29b&summary=true&limit=1&after=NTk5NjY1MTMwMTg2MjY0"
#         },
#         "summary": {
#             "can_like": false,
#             "has_liked": false,
#             "total_count": 22
#         }
#     },
#     "link": "http://nyti.ms/1qD0ygD",
#     "message": "He wiped blood onto his 5-year-old daughter's shirt. Then he changed his clothes and fled the scene.",
#     "name": "Father Tried to Blame 5-Year-Old With Killing of 4-Year-Old, Police Say",
#     "shares": {
#         "count": 13
#     },
#     "type": "link"
# }

# %%
def processFacebookPageFeedStatus(status):
    
    # The status is now a Python dictionary, so for top-level items,
    # we can simply call the key.
    
    # Additionally, some items may not always exist,
    # so must check for existence first
    
    status_id = status['id']
    status_message = '' if 'message' not in status.keys() else status['message'].encode('utf-8')
    link_name = '' if 'name' not in status.keys() else status['name'].encode('utf-8')
    status_type = status['type']
    status_link = '' if 'link' not in status.keys() else status['link']
    
    
    # Time needs special care since a) it's in UTC and
    # b) it's not easy to use in statistical programs.
    
    status_published = datetime.datetime.strptime(status['created_time'],'%Y-%m-%dT%H:%M:%S+0000')
    status_published = status_published + datetime.timedelta(hours=-5) # EST
    status_published = status_published.strftime('%Y-%m-%d %H:%M:%S') # best time format for spreadsheet programs
    
    # Nested items require chaining dictionary keys.
    
    num_likes = 0 if 'likes' not in status.keys() else status['likes']['summary']['total_count']
    num_comments = 0 if 'comments' not in status.keys() else status['comments']['summary']['total_count']
    num_shares = 0 if 'shares' not in status.keys() else status['shares']['count']
    
    # return a tuple of all processed data
    return (status_id, status_message, link_name, status_type, status_link,
           status_published, num_likes, num_comments, num_shares)

processed_test_status = processFacebookPageFeedStatus(test_status)
print processed_test_status
# Out:
# (u'5281959998_10150793902249999', "He wiped blood onto his 5-year-old daughter's shirt. Then he changed his clothes and fled the scene.", 'Father Tried to Blame 5-Year-Old With Killing of 4-Year-Old, Police Say', u'link', u'http://nyti.ms/1qD0ygD', '2016-04-19 15:26:06', 22, 3, 13)

# %%
def scrapeFacebookPageFeedStatus(page_id, access_token):
    with open('%s_facebook_statuses.csv' % page_id, 'wb') as file:
        w = csv.writer(file)
        w.writerow(["status_id", "status_message", "link_name", "status_type", "status_link",
           "status_published", "num_likes", "num_comments", "num_shares"])
        
        has_next_page = True
        num_processed = 0   # keep a count on how many we've processed
        scrape_starttime = datetime.datetime.now()
        
        print "Scraping %s Facebook Page: %s\n" % (page_id, scrape_starttime)
        
        statuses = getFacebookPageFeedData(page_id, access_token, 100)
        
        while has_next_page:
            for status in statuses['data']:
                w.writerow(processFacebookPageFeedStatus(status))
                
                # output progress occasionally to make sure code is not stalling
                num_processed += 1
                if num_processed % 1000 == 0:
                    print "%s Statuses Processed: %s" % (num_processed, datetime.datetime.now())
                    
            # if there is no next page, we're done.
            if 'paging' in statuses.keys():
                statuses = json.loads(request_until_succeed(statuses['paging']['next']))
            else:
                has_next_page = False
                
        
        print "\nDone!\n%s Statuses Processed in %s" % (num_processed, datetime.datetime.now() - scrape_starttime)


scrapeFacebookPageFeedStatus(page_id, access_token)
# Out:
# Scraping nytimes Facebook Page: 2016-04-19 13:41:26.016741
#
# 1000 Statuses Processed: 2016-04-19 13:42:07.108040
# 2000 Statuses Processed: 2016-04-19 13:42:47.508978
# 3000 Statuses Processed: 2016-04-19 13:43:29.922538
# 4000 Statuses Processed: 2016-04-19 13:44:10.557863
# 5000 Statuses Processed: 2016-04-19 13:44:59.414747
# 6000 Statuses Processed: 2016-04-19 13:45:38.018267
# 7000 Statuses Processed: 2016-04-19 13:46:22.777741
# HTTP Error 500: Internal Server Error
# Error for URL https://graph.facebook.com/v2.6/5281959998/feed?fields=message,link,created_time,type,name,id,likes.limit%281%29.summary%28true%29,comments.limit%281%29.summary%28true%29,shares&limit=100&__paging_token=enc_AdAn8E6iddlsECrCRLbGRYvA3fQBcwmB7dAI9oKNHcPsuZAlvGJkXjZBw0ThnZC0i6R1ilASzqHv76HITgwlKTYnuSM&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&until=1446123307: 2016-04-19 13:47:01.933752
# 8000 Statuses Processed: 2016-04-19 13:47:17.341622
# 9000 Statuses Processed: 2016-04-19 13:47:59.533960
# 10000 Statuses Processed: 2016-04-19 13:48:47.770203
# 11000 Statuses Processed: 2016-04-19 13:49:32.633903
# HTTP Error 500: Internal Server Error
# Error for URL https://graph.facebook.com/v2.6/5281959998/feed?fields=message,link,created_time,type,name,id,likes.limit%281%29.summary%28true%29,comments.limit%281%29.summary%28true%29,shares&limit=100&__paging_token=enc_AdAu2CYWYls0MNDMedJES8f7uExLuNLDLzQQO13ctlFP1MWSThX4rsj8ZANkwHr3pSQtqZB5XeiZAV3NKYjZCeOvozpP&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&until=1438124101: 2016-04-19 13:50:12.916743
# 12000 Statuses Processed: 2016-04-19 13:50:23.896696
# HTTP Error 500: Internal Server Error
# Error for URL https://graph.facebook.com/v2.6/5281959998/feed?fields=message,link,created_time,type,name,id,likes.limit%281%29.summary%28true%29,comments.limit%281%29.summary%28true%29,shares&limit=100&__paging_token=enc_AdCXZAozB7uPeLfJibuKtp4p2bLedzG551o3XgIFiVohLUUle9K7koYRg5ZBwJYXA6lDpfUiGOcwxorHiYB47n0ZCub&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&until=1436504100: 2016-04-19 13:50:53.152448
# 13000 Statuses Processed: 2016-04-19 13:51:14.190916
# 14000 Statuses Processed: 2016-04-19 13:51:55.072545
# 15000 Statuses Processed: 2016-04-19 13:52:45.648401
# 16000 Statuses Processed: 2016-04-19 13:53:34.175613
# [Errno 54] Connection reset by peer
# Error for URL https://graph.facebook.com/v2.6/5281959998/feed?fields=message,link,created_time,type,name,id,likes.limit%281%29.summary%28true%29,comments.limit%281%29.summary%28true%29,shares&limit=100&__paging_token=enc_AdAN7eG1nfZAH1k1mohUMVlCZCoZAEEKtYGS41B4jC8JVMBZBwTIry3RhD4i7wT0QWC4SvRJliRbZCechPXrEw9Nj0lZBc&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&until=1429745106: 2016-04-19 13:53:46.851522
# [Errno 54] Connection reset by peer
# Error for URL https://graph.facebook.com/v2.6/5281959998/feed?fields=message,link,created_time,type,name,id,likes.limit%281%29.summary%28true%29,comments.limit%281%29.summary%28true%29,shares&limit=100&__paging_token=enc_AdAr3tZAIzIbIXUn73xHyFl6StxEsZAJcMd0p8F0U8NZCi9iCz55mmpJf2G7HInPaF1hmITfu3dskHEHP4VlVZCcftBD&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&until=1429203796: 2016-04-19 13:54:07.637742
# 17000 Statuses Processed: 2016-04-19 13:54:33.634322
# 18000 Statuses Processed: 2016-04-19 13:55:27.545265
# 19000 Statuses Processed: 2016-04-19 13:56:16.699055
# HTTP Error 500: Internal Server Error
# Error for URL https://graph.facebook.com/v2.6/5281959998/feed?fields=message,link,created_time,type,name,id,likes.limit%281%29.summary%28true%29,comments.limit%281%29.summary%28true%29,shares&limit=100&__paging_token=enc_AdAZC4ZAT7Ozd1pY5q9uZB9kG4HZCJ8mLY4K1imkwvPdRsTZBI9kIF02nqs5g7osmJkRS5rTByn4ZAaJGKzXMc3cvoCXQx&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&until=1423900891: 2016-04-19 13:56:30.115638
# 20000 Statuses Processed: 2016-04-19 13:57:08.606726
# 21000 Statuses Processed: 2016-04-19 13:57:46.399840
# HTTP Error 500: Internal Server Error
# Error for URL https://graph.facebook.com/v2.6/5281959998/feed?fields=message,link,created_time,type,name,id,likes.limit%281%29.summary%28true%29,comments.limit%281%29.summary%28true%29,shares&limit=100&__paging_token=enc_AdDHUY3vCmHUYv1piG0MDrBwxsF6nZCQ3xkh8sPpokxn02VBGTjxE6dK2PAAJS6B9fXQD0S1JcDo3dTi5sPkuJoJ6&access_token=1588347538160720|d77eae2a264f512a1acb6f84df6bc29b&until=1418924925: 2016-04-19 13:58:12.873895
# 22000 Statuses Processed: 2016-04-19 13:58:36.259349
# 23000 Statuses Processed: 2016-04-19 13:59:15.703407
# 24000 Statuses Processed: 2016-04-19 13:59:55.663681
# 25000 Statuses Processed: 2016-04-19 14:00:41.700673
# 26000 Statuses Processed: 2016-04-19 14:01:23.492839
# 27000 Statuses Processed: 2016-04-19 14:02:00.753927
# 28000 Statuses Processed: 2016-04-19 14:02:48.831423
# 29000 Statuses Processed: 2016-04-19 14:03:32.105826
# 30000 Statuses Processed: 2016-04-19 14:04:16.354305
# 31000 Statuses Processed: 2016-04-19 14:04:57.198684
# 32000 Statuses Processed: 2016-04-19 14:05:37.770619
# 33000 Statuses Processed: 2016-04-19 14:06:19.736270
# 34000 Statuses Processed: 2016-04-19 14:07:00.304025
# 35000 Statuses Processed: 2016-04-19 14:07:40.154894
# 36000 Statuses Processed: 2016-04-19 14:08:19.543638
# 37000 Statuses Processed: 2016-04-19 14:09:12.195359
# 38000 Statuses Processed: 2016-04-19 14:09:51.086278
#
# Done!
# 38061 Statuses Processed in 0:28:25.164837
