# %%
import pandas as pd
import numpy as np
import random

from sklearn.cross_validation import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

import sklearn.metrics as skm


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_data_csv = pd.read_csv('result_05.csv')

# %%
len(df_data_csv)
# Out:
# 438

# %%
df_data_csv
# Out:
#      Unnamed: 0  week  twitter_per_hour  pos_rate  neg_rate  ratio_pos_neg  \
# 0             0    14          1.054018  0.888889  0.000000      17.000000
# 1             1    15         12.939767  0.915825  0.010101      68.250000
# 2             2    16          3.948090  0.950000  0.000000      58.000000
# 3             0    14          7.787343  0.248322  0.067114       3.454545
# 4             1    15         82.805178  0.199193  0.056480       3.504425
# 5             2    16         45.034946  0.141700  0.026991       5.047619
# 6             0    14         10.903069  0.330049  0.024631      11.333333
# 7             1    15         83.601796  0.240080  0.019588      11.975000
# 8             2    16         31.754478  0.228007  0.014363      14.222222
# 9             0    15          0.005952  0.000000  0.000000       1.000000
# 10            0    15          0.005952  0.000000  0.000000       1.000000
# 11            0    14          0.005952  0.261467  0.016951      15.331169
# 12            0    14          0.005952  0.000000  0.000000       1.000000
# 13            0    14          0.005952  1.000000  0.000000       3.000000
# 14            1    16          0.005952  1.000000  0.000000       2.000000
# 15            0    14          0.005952  0.000000  0.000000       1.000000
# 16            0    14          0.005952  0.000000  0.000000       1.000000
# 17            1    16          0.419589  0.000000  0.000000       1.000000
# 18            0    14          0.005952  0.000000  0.000000       1.000000
# 19            0    14          0.005952  0.000000  0.050000       0.500000
# 20            1    16          1.191790  0.000000  0.000000       1.000000
# 21            0    14          0.005952  0.000000  0.000000       1.000000
# 22            1    15          0.005952  0.000000  0.000000       1.000000
# 23            2    16          0.005952  0.000000  0.000000       1.000000
# 24            0    15          0.005952  0.000000  0.000000       1.000000
# 25            0    15          0.005952  0.000000  0.000000       1.000000
# 26            0    14          0.005952  1.000000  0.000000       2.000000
# 27            0    14          0.005952  0.000000  0.000000       1.000000
# 28            0    14          0.005952  0.666667  0.000000       3.000000
# 29            1    16          1.000695  0.000000  0.000000       1.000000
# ..          ...   ...               ...       ...       ...            ...
# 408           0    14          0.005952  0.000000  0.000000       1.000000
# 409           0    14          0.005952  0.000000  1.000000       0.166667
# 410           1    16          0.881921  0.000000  0.900000       0.100000
# 411           0    14          0.005952  0.000000  0.000000       1.000000
# 412           0    14          0.005952  1.000000  0.000000      20.000000
# 413           1    16          0.552198  1.000000  0.000000       6.000000
# 414           0    15          0.005952  0.000000  0.000000       1.000000
# 415           0    15          0.005952  0.000000  0.000000       1.000000
# 416           0    14          0.005952  0.000000  0.000000       1.000000
# 417           0    14          0.005952  0.000000  0.000000       1.000000
# 418           0    14          0.005952  1.000000  0.000000       3.000000
# 419           1    16          0.005952  1.000000  0.000000       2.000000
# 420           0    14          0.005952  0.000000  0.000000       1.000000
# 421           0    14          0.005952  0.000000  0.000000       1.000000
# 422           0    16          0.005952  0.000000  0.000000       1.000000
# 423           0    14          0.005952  0.000000  0.000000       1.000000
# 424           1    15          0.005952  0.000000  0.000000       1.000000
# 425           2    16          0.005952  0.000000  0.000000       1.000000
# 426           0    14          0.005952  0.000000  0.000000       1.000000
# 427           0    14          0.005952  0.068966  0.000000       3.000000
# 428           1    16          0.693751  0.000000  0.000000       1.000000
# 429           0    15          0.005952  0.000000  0.000000       1.000000
# 426         Work From Home%FIFTH HARMONY        143           13           16
# 427         Work From Home%FIFTH HARMONY        143           13           16
# 428         Work From Home%FIFTH HARMONY        143           10           12
# 429                         Work%RIHANNA        144            1            1
# 430                         Work%RIHANNA        144            1            1
# 431                         Work%RIHANNA        144            1            1
# 432      You Should Be Here%COLE SWINDELL       145           32           38
# 433      You Should Be Here%COLE SWINDELL       145           32           32
# 434      You Should Be Here%COLE SWINDELL       145           31           32
# 435                     Youth%TROYE SIVAN       146           23           58
# 436                     Youth%TROYE SIVAN       146           23           58
# 437                     Youth%TROYE SIVAN       146           34           36
#
#      past_rank_3  past_rank_4  next_rank
# 0             89           95        101
# 1            101           89        101
# 2            101          101          0
# 3             25           29         18
# 4             21           25         18
# 5             18           21          0
# 6             35           30         40
# 7             39           35         40
# 8             40           39          0
# 9              5            9          2
# 10             5            9          2
# 11             9           12          2
# 12            75           76         70
# 13            75           76         70
# 14            76           77          0
# 15            41           33        101
# 16            41           33        101
# 17            65           53          0
# 18           101          101        101
# 19           101          101        101
# 20           101          101          0
# 21           101          101         91
# 22           101          101         91
# 23           101          101          0
# 24            83          101        101
# 25            83          101        101
# 26           101          101        101
# 27            47           40        101
# 28            47           40        101
# 29           101          101          0
# ..           ...          ...        ...
# 408           29           25         41
# 409           29           25         41
# 410           36           34          0
# 411           23           18         58
# 412           23           18         58
# 413           34           28          0
# 414           46           44         49
# 415           46           44         49
# 416           44           42         49
# 417           80           91         60
# 418           80           91         60
# 419           66           69          0
# 420          101           46        101
# 421          101           46        101
# 422          101          101          0
# 423          101          101         87
# 424          101          101         87
# 425          101          101          0
# 426           12          101         10
# 427           12          101         10
# 428           13           16          0
# 429            1            1          1
# 430            1            1          1
# 431            1            1          1
# 432           43           50         31
# 433           38           43         31
# 434           32           38          0
# 435           58           67         34
# 436           58           67         34
# 437           23           58          0
#
# [438 rows x 16 columns]

# %%
def separate_data(data):
    
    df = data[(data['next_rank'] < 101) & (data['next_rank'] > 0) & (data['current_rank'] < 101)]
    
    df0 = df[df['past_rank_1']>100]
    df1 = df[df['past_rank_1'] <=100]
    
    df1_only = df1[df1['past_rank_2']>100]
    df2 = df1[df1['past_rank_2'] <=100]
    
    df2_only = df2[df2['past_rank_3']>100]
    df3 = df2[df2['past_rank_3'] <=100]
    
    df3_only = df3[df3['past_rank_4']>100]
    df4 = df3[df3['past_rank_4'] <=100]
    
    return df, df0, df1, df1_only, df2, df2_only, df3, df3_only, df4

# %%
df, df0, df1, df1_only, df2, df2_only, df3, df3_only, df4  = separate_data(df_data_csv)

# %%
print len(df), len(df1)
# Out:
# 193 186

# %%
def get_dataForAnalysis_cla(df):
    df['y_num'] = df['next_rank'] - df['current_rank'] 
    df['y_binary'] =df['y_num'].apply(lambda x : 1 if x <= 0 else 0)  
    df['diff_past_1_temp'] = df['current_rank'] - df['past_rank_1']
    df['diff_past_1'] = 0
    df['diff_past_1'][df['past_rank_1'] !=101 ] = df['diff_past_1_temp'][df['past_rank_1'] !=101 ]
        
    col = ['current_rank','twitter_per_hour','pos_rate','neg_rate',
           'ratio_pos_neg','favorite_rate','diff_past_1','y_binary']
    return df[col]

# %%
def get_dataForAnalysis_reg(df):
    df['y_num'] = df['next_rank'] - df['current_rank'] 
    df['y_binary'] =df['y_num'].apply(lambda x : 1 if x <= 0 else 0)  
    df['diff_past_1_temp'] = df['current_rank'] - df['past_rank_1']
    df['diff_past_1'] = 0
    df['diff_past_1'][df['past_rank_1'] !=101 ] = df['diff_past_1_temp'][df['past_rank_1'] !=101 ]
    
    col = ['current_rank','twitter_per_hour','pos_rate','neg_rate',
           'ratio_pos_neg','favorite_rate','diff_past_1','y_num']
    return df[col]

# %%
df_data = get_dataForAnalysis_cla(df1)
df_data
# Out:
# /Users/Yeongcheon/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/Yeongcheon/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/Yeongcheon/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Yeongcheon/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Yeongcheon/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Yeongcheon/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:4059: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /Users/Yeongcheon/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#      current_rank  twitter_per_hour  pos_rate  neg_rate  ratio_pos_neg  \
# 3              18          7.787343  0.248322  0.067114       3.454545
# 4              18         82.805178  0.199193  0.056480       3.504425
# 6              39         10.903069  0.330049  0.024631      11.333333
# 7              40         83.601796  0.240080  0.019588      11.975000
# 9               2          0.005952  0.000000  0.000000       1.000000
# 10              2          0.005952  0.000000  0.000000       1.000000
# 11              2          0.005952  0.261467  0.016951      15.331169
# 12             73          0.005952  0.000000  0.000000       1.000000
# 13             73          0.005952  1.000000  0.000000       3.000000
# 30             30          0.005952  0.000000  0.000000       1.000000
# 31             30          0.005952  0.500000  0.000000       2.000000
# 42             72          0.005952  0.000000  0.000000       1.000000
# 43             76          0.005952  0.000000  0.000000       1.000000
# 45             65          0.005952  0.000000  0.000000       1.000000
# 46             66          0.005952  0.000000  0.000000       1.000000
# 60              9          0.005952  0.000000  0.000000       1.000000
# 61              9          0.005952  0.480000  0.060000       6.250000
# 63             61          0.005952  0.000000  0.000000       1.000000
# 64             61          0.005952  0.000000  0.000000       1.000000
# 69             71          0.005952  0.000000  0.000000       1.000000
# 70             71          0.005952  1.000000  0.000000      21.000000
# 75             66          0.005952  0.000000  0.000000       1.000000
# 76             66          0.005952  0.036554  0.013055       2.636364
# 78             55          0.005952  0.000000  0.000000       1.000000
# 79             55          0.005952  0.000000  0.000000       1.000000
# 84             68          0.005952  0.000000  0.000000       1.000000
# 85             62          0.005952  0.000000  0.000000       1.000000
# 87             13          0.005952  0.000000  1.000000       0.500000
# 88             12          1.383152  0.000000  1.000000       0.058824
# 96             44          0.005952  0.000000  0.000000       1.000000
# ..            ...               ...       ...       ...            ...
# 360            74          0.005952  0.000000  0.000000       1.000000
# 361            74          0.005952  0.591909  0.018470      30.636364
# 366            90          0.005952  0.000000  0.000000       1.000000
# 367            90          0.005952  0.973978  0.022305      37.571429
# 369            28          0.005952  0.000000  0.000000       1.000000
# 370            28          0.005952  0.000000  0.000000       1.000000
# 372            69          0.005952  0.000000  0.000000       1.000000
# 373            69          0.005952  1.000000  0.000000       5.000000
# 375            57          0.005952  0.000000  0.000000       1.000000
# 376            53          0.005952  0.000000  0.000000       1.000000
# 381            86          0.005952  0.000000  0.000000       1.000000
# 382            86          0.005952  0.000000  0.000000       1.000000
# 408            37          0.005952  0.000000  0.000000       1.000000
# 409            37          0.005952  0.000000  1.000000       0.166667
# 411            50          0.005952  0.000000  0.000000       1.000000
# 412            50          0.005952  1.000000  0.000000      20.000000
# 414            49          0.005952  0.000000  0.000000       1.000000
# 415            49          0.005952  0.000000  0.000000       1.000000
# 416            45          0.005952  0.000000  0.000000       1.000000
# 417            58          0.005952  0.000000  0.000000       1.000000
# 418            58          0.005952  1.000000  0.000000       3.000000
# 426            12          0.005952  0.000000  0.000000       1.000000
# 427            12          0.005952  0.068966  0.000000       3.000000
# 429             1          0.005952  0.000000  0.000000       1.000000
# 430             1          0.005952  0.000000  0.000000       1.000000
# 431             1          0.005952  0.588401  0.040617      14.414894
# 432            32          0.005952  0.000000  0.000000       1.000000
# 433            31          0.005952  0.000000  0.000000       1.000000
# 435            36          0.005952  0.000000  0.000000       1.000000
# 436            36          0.005952  0.651429  0.000000     115.000000
#
#      favorite_rate  diff_past_1  y_binary
# 3         0.355705            0         1
# 4         0.537569            0         1
# 6         0.290640           -1         0
# 7         0.374184            1         1
# 9         0.000000            0         1
# 10        0.000000            0         1
# 11        4.460558           -1         1
# 12        0.000000           -3         1
# 13        0.000000           -3         1
# 30        0.000000            1         0
# 31        1.500000            1         0
# 42        0.000000           20         0
# 43        0.000000            4         1
# 45        0.000000            8         0
# 46        0.000000            1         1
# 60        0.000000            0         0
# 61        0.420000            0         0
# 63        0.000000           19         1
# 64        0.000000           19         1
# 69        0.000000          -16         1
# 70        0.450000          -16         1
# 75        0.000000          -11         1
# 76        0.074413          -11         1
# 78        0.000000           -5         0
# 79        0.000000           -5         0
# 84        0.000000           -6         1
# 85        0.000000           -6         1
# 87        1.000000            3         1
# 88        0.250000           -1         1
# 96        0.000000            1         0
# ..             ...          ...       ...
# 360       0.000000           -6         1
# 361       7.330695           -6         1
# 366       0.000000           -2         1
# 367       0.234201           -2         1
# 369       0.000000            3         0
# 370       0.000000            3         0
# 372       0.000000           -4         1
# 373       0.000000           -4         1
# 375       0.000000          -11         1
# 376       0.000000           -4         1
# 381       0.000000           23         1
# 382       0.000000           23         1
# 408       0.000000            1         0
# 409       0.000000            1         0
# 411       0.000000           16         0
# 412       0.000000           16         0
# 414       0.000000            4         1
# 415       0.000000            4         1
# 416       0.000000           -4         0
# 417       0.000000           -8         0
# 418       0.000000           -8         0
# 426       0.000000           -1         1
# 427       0.482759           -1         1
# 429       0.000000            0         1
# 430       0.000000            0         1
# 431       2.038879            0         1
# 432       0.000000            0         1
# 433       0.000000           -1         1
# 435       0.000000           13         1
# 436       0.571429           13         1
#
# [186 rows x 8 columns]

# %%
X = df_data.copy()
y = X.pop('y_binary').values
X = X.values

# %%
random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, y_train)
y_pred = RFC.predict(X_test)
y_pred_prob = RFC.predict_proba(X_test)[:,1]

print "RandomForestClassifier"
print "Accuracy : {}".format(RFC.score(X_test, y_test))
print "Precession: {}".format(skm.precision_score(y_test, y_pred))
print "recall: {}".format(skm.recall_score(y_test, y_pred))
print "roc_auc: {}".format(skm.roc_auc_score(y_test, y_pred_prob))
# Out:
# RandomForestClassifier
# Accuracy : 0.787234042553
# Precession: 0.857142857143
# recall: 0.857142857143
# roc_auc: 0.730952380952

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
plt.figure(figsize=(10,8))
warnings.filterwarnings('ignore')
sns.set(style="white", color_codes=True)
sns.stripplot(x='y_binary', y='twitter_per_hour', data=df_data, jitter=True)
plt.title('Analysis on the number of twitter per hour', fontsize = 25)
plt.xlabel('0=down,           1 = up&stay', fontsize = 20)
plt.ylabel('twitter per hour', fontsize = 20)
sns.despine()
plt.savefig('twitter_hour.png')
